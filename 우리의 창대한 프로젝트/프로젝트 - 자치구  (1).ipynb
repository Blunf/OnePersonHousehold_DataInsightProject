# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc
font_path = "NanumSquareNeo-aLt.ttf"   #폰트파일의 위치
font_name = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font_name)
print("work ")
# Out:
# work

# %%
one = pd.read_csv ('1인가구(연령별)_20230313134011.csv')

# %%
position1 = one[['자치구별(2)', '2021']]
position1
# Out:
#     자치구별(2)     2021
# 0   자치구별(2)       합계
# 1   자치구별(2)       소계
# 2   자치구별(2)        계
# 3        소계  1489893
# 4       종로구    27308
# 5        중구    24544
# 6       용산구    39270
# 7       성동구    44946
# 8       광진구    66140
# 9      동대문구    65290
# 10      중랑구    60487
# 11      성북구    64985
# 12      강북구    48428
# 13      도봉구    37853
# 14      노원구    60647
# 15      은평구    62447
# 16     서대문구    52792
# 17      마포구    67162
# 18      양천구    42973
# 19      강서구    94436
# 20      구로구    54980
# 21      금천구    46827
# 22     영등포구    69806
# 23      동작구    68231
# 24      관악구   136255
# 25      서초구    45933
# 26      강남구    71986
# 27      송파구    79262
# 28      강동구    56905

# %%
position1 = position1.drop([0,1,2,3])
position1
# Out:
#    자치구별(2)    2021
# 4      종로구   27308
# 5       중구   24544
# 6      용산구   39270
# 7      성동구   44946
# 8      광진구   66140
# 9     동대문구   65290
# 10     중랑구   60487
# 11     성북구   64985
# 12     강북구   48428
# 13     도봉구   37853
# 14     노원구   60647
# 15     은평구   62447
# 16    서대문구   52792
# 17     마포구   67162
# 18     양천구   42973
# 19     강서구   94436
# 20     구로구   54980
# 21     금천구   46827
# 22    영등포구   69806
# 23     동작구   68231
# 24     관악구  136255
# 25     서초구   45933
# 26     강남구   71986
# 27     송파구   79262
# 28     강동구   56905

# %%
position1['2021']=position1['2021'].astype(int)

# %%
position1.plot.bar(x='자치구별(2)', y='2021')
# Out:
# <Axes: xlabel='자치구별(2)'>
# findfont: Font family 'NanumSquare Neo Light' not found.
# findfont: Font family 'NanumSquare Neo Light' not found.
# /Users/besuperst/Library/Python/3.13/lib/python/site-packages/IPython/core/events.py:82: UserWarning: Glyph 51333 (\N{HANGUL SYLLABLE JONG}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# /Users/besuperst/Library/Python/3.13/lib/python/site-packages/IPython/core/events.py:82: UserWarning: Glyph 47196 (\N{HANGUL SYLLABLE RO}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# /Users/besuperst/Library/Python/3.13/lib/python/site-packages/IPython/core/events.py:82: UserWarning: Glyph 44396 (\N{HANGUL SYLLABLE GU}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# findfont: Font family 'NanumSquare Neo Light' not found.
# /Users/besuperst/Library/Python/3.13/lib/python/site-packages/IPython/core/events.py:82: UserWarning: Glyph 51473 (\N{HANGUL SYLLABLE JUNG}) missing from font(s) DejaVu Sans.
# ...
